# %% [markdown]
# # 2ο Set Ασκήσεων Python – Βασικό Επίπεδο
# Καλύπτουν Variables, Numbers, Strings, Boolean, Lists, Tuples.

# %% [markdown]
# ### 1. Δημιούργησε μια μεταβλητή x=10 και τύπωσε την.

# %%
x=10
print(x);
# Out:
# 10

# %% [markdown]
# ### 2. Πρόσθεσε δύο αριθμούς και τύπωσε το αποτέλεσμα.

# %%
a=14+10
print(a);
# Out:
# 24

# %% [markdown]
# ### 3. Στην πρόταση 'I have a dream' μέτρησε τα γράμματα της 2ης λέξης.

# %%
'I have a dream'.split(" ")[1:3]
# Out:
# ['have', 'a']

# %% [markdown]
# ### 4. Έλεγξε αν 15 > 10.

# %%
15>10
# Out:
# True

# %% [markdown]
# ### 5. Μετέτρεψε το '42' σε αριθμό και πρόσθεσε 8.

# %%
n=42
print(n+8);
# Out:
# 50

# %% [markdown]
# ### 6. Δημιούργησε λίστα με τρία ονόματα και τύπωσε το δεύτερο.

# %%
a=["niko","filia","sofia"]
print(a[1]);
# Out:
# filia

# %% [markdown]
# ### 7. Μέτρησε τα γράμματα του 'Knowledge is power'.

# %%
a='Knowledge is power'
lett=len (a)
print(lett)
# Out:
# 18

# %% [markdown]
# ### 8. Δημιούργησε tuple με τρεις αριθμούς και τύπωσε το άθροισμα.

# %%
a=sum((3,5,7))
print(a)
# Out:
# 15

# %% [markdown]
# ### 9. Από τη φράση 'Stay hungry, stay foolish' τύπωσε την τελευταία λέξη.

# %%
a=['Stay','hungry','stay','foolish']
print(a[3])
# Out:
# foolish

# %% [markdown]
# ### 10. Έλεγξε αν ο αριθμός 100 είναι άρτιος με χρήση %.

# %%
print(100 % 2==0)
# Out:
# True

# %% [markdown]
# ### 11. Αντάλλαξε τις τιμές δύο μεταβλητών.

# %%
a=2
b=4
c=b
b=a
a=c
print(a,b)
# Out:
# 4 2

# %% [markdown]
# ### 12. Βρες το μεγαλύτερο από τρεις αριθμούς με τη συνάρτηση max().

# %%
a=[23,445,43]
max(a)
# Out:
# 445

# %% [markdown]
# ### 13. Αντιστροφή του string 'hello'.

# %%
text = "hello"
reversed_text = text[::-1]
print(reversed_text)
# Out:
# olleh

# %% [markdown]
# ### 14. Βρες τον μέσο όρο των 2,4,6,8 χωρίς βρόχο.

# %%
averang=(2+4+6+8)/4
print(averang);
# Out:
# 5.0

# %% [markdown]
# ### 15. Έλεγξε αν μια λίστα είναι άδεια χρησιμοποιώντας len().

# %%
my_list=[]
if len(my_list)==0:
    print("Δεν είναι άδεια")
else:
    print("Είναι άδεια")
# Out:
# Δεν είναι άδεια

# %% [markdown]
# ### 16. Μέτρησε πόσα 'a' υπάρχουν στη φράση 'Carpe diem'.

# %%
phrase = "Carpe diem"
count_a = phrase.count('a')
print(count_a)
# Out:
# 1

# %% [markdown]
# ### 17. Συνδύασε δύο λίστες.

# %%
a=["love"]
b=["to"]
print(a+b);
# Out:
# ['love', 'to']

# %% [markdown]
# ### 18. Ταξινόμησε τη λίστα [10,3,7,1].

# %%
a=[10,3,7,1]
sorted(a)
# Out:
# [1, 3, 7, 10]

# %% [markdown]
# ### 19. Έλεγξε αν το 2 υπάρχει στο tuple (1,2,3).

# %%
t = (1, 2, 3)
two=(t)
count=two.count(2)
print(count)
# Out:
# 1

# %% [markdown]
# ### 20. Από τη λίστα [2,3,4] υπολόγισε το γινόμενο με απλό πολλαπλασιασμό (χωρίς for).

# %%
a=[2,3,4]
product=a[0] * a[1] * a[2]
print(product);
# Out:
# 24

# %% [markdown]
# ### 21. Μέτρησε τις λέξεις του 'To be or not to be'.

# %%
phrase = 'To be or not to be'
print(len(phrase.split()))
# Out:
# 6

# %% [markdown]
# ### 22. Αντικατέστησε 'bad' με 'good' στη φράση 'This is bad'.

# %% [markdown]
# ### 26. Με slicing πάρε τα τρία πρώτα στοιχεία από [1,2,3,4].

# %% [markdown]
# ### 27. Μετέτρεψε το 'hello' σε tuple χαρακτήρων.

# %% [markdown]
# ### 28. Από 'The only limit is your mind' τύπωσε την τρίτη λέξη.

# %% [markdown]
# ### 29. Έλεγξε αν δύο strings είναι αναγραμματισμοί χρησιμοποιώντας sorted().

# %% [markdown]
# ### 30. Υπολόγισε πόσα στοιχεία στη λίστα [10,20,30,40,50] είναι > μέσου όρου (χειροκίνητα).

# %% [markdown]
# ### 31. Τύπωσε τον πρώτο χαρακτήρα του 'Python'.

# %% [markdown]
# ### 32. Αντίστρεψε τη λίστα [1,2,3] με slicing.

# %% [markdown]
# ### 33. Από τη φράση 'Carpe diem' πάρε μόνο τη λέξη 'diem'.

# %% [markdown]
# ### 34. Πολλαπλασίασε δύο αριθμούς αποθηκευμένους σε μεταβλητές.

# %% [markdown]
# ### 35. Ένωσε τις λέξεις 'Hello' και 'World' με κενό.

# %% [markdown]
# ### 36. Βρες το μήκος της λίστας ['a','b','c','d'].

# %% [markdown]
# ### 37. Με tuple unpacking αποθήκευσε τα στοιχεία (5,10) σε δύο μεταβλητές.

# %% [markdown]
# ### 38. Από τη λίστα [10,20,30,40] πάρε τα δύο μεσαία στοιχεία.

# %% [markdown]
# ### 39. Μέτρησε πόσες λέξεις έχει το 'Knowledge itself is power'.

# %% [markdown]
# ### 40. Αφαίρεσε δύο αριθμούς αποθηκευμένους σε μεταβλητές.

# %% [markdown]
# ### 41. Χρησιμοποιώντας slicing πάρε κάθε δεύτερο γράμμα από τη λέξη 'Motivation'.

# %% [markdown]
# ### 42. Από το tuple (1,2,3,4,5,6) πάρε τα στοιχεία 2 έως 5.

# %% [markdown]
# ### 43. Στη φράση 'Stay positive work hard make it happen' τύπωσε την 4η λέξη.

# %% [markdown]
# ### 44. Υπολόγισε την απόλυτη τιμή του -123 χρησιμοποιώντας abs().

# %% [markdown]
# ### 45. Ένωσε τρία strings σε μία πρόταση: 'Coding', 'is', 'fun'.

# %% [markdown]
# ### 46. Στη λίστα [5,10,15,20,25] τύπωσε τα τρία τελευταία στοιχεία.

# %% [markdown]
# ### 47. Μετέτρεψε τον αριθμό 12345 σε string και πάρε τον 3ο χαρακτήρα.

# %% [markdown]
# ### 48. Φτιάξε tuple με τα γράμματα της λέξης 'Success' χρησιμοποιώντας tuple().

# %% [markdown]
# ### 49. Από τη λίστα ['red','green','blue','yellow'] τύπωσε το προτελευταίο στοιχείο.

# %% [markdown]
# ### 50. Στη φράση 'The journey of a thousand miles begins with one step' τύπωσε την 6η λέξη.
