# %% [markdown]
# # Μαθηματικές Εξισώσεις
# Υπολογίστε τις ακόλουθες εκφράσεις σε Python και επαληθευστε το αποτέλεσμα.

# %% [markdown]
# ## Παράδειγμα
# ## Υπολόγισε την ακόλουθη έκφραση στην Python:$$ (5 + 3) \times 2^3 - \frac{40}{2 + 3} $$

# %%
(5+3)*(2**3) - (40//(2+3))
# Out:
# 56

# %% [markdown]
# ## Άσκηση 1
#
# $$ (23 + 12) \times 5^3 - \frac{120}{7 + 2} $$

# %%
(23 + 12) * 5**3 - 120/(7 + 2)
# Out:
# 4361.666666666667

# %% [markdown]
# ### Αποτέλεσμα: **4361.666667**

# %% [markdown]
# ## Άσκηση 2
#
# $$ ((45 - 17)(9 - 3 \times 2))^2 $$

# %%
((45 - 17) * (9 - 3*2))**2
# Out:
# 7056

# %% [markdown]
# ### Αποτέλεσμα: **7056**

# %% [markdown]
# ## Άσκηση 3
#
# $$ \frac{9^4}{50 \bmod 6} $$

# %%
9**4 / (50 % 6)
# Out:
# 3280.5

# %% [markdown]
# ### Αποτέλεσμα: **3280.5**

# %% [markdown]
# ## Άσκηση 4
#
# $$ (50 + 22) \times \frac{16}{5 - 2.5} $$

# %%
(50 + 22) * 16 / (5 - 2.5)
# Out:
# 460.8

# %% [markdown]
# ### Αποτέλεσμα: **460.8**

# %% [markdown]
# ## Άσκηση 5
#
# $$ (8 \times 7)^3 - \frac{250}{3 + 4\times 2} $$

# %%
(8 * 7)**3 - 250 / (3 + 4*2)
# Out:
# 175593.27272727274

# %% [markdown]
# ### Αποτέλεσμα: **175593.272727**

# %% [markdown]
# ## Άσκηση 6
#
# $$ \frac{32}{4}(15 - 5) + 4^5 $$

# %%
(32//4) * (15 - 5) + 4**5
# Out:
# 1104

# %% [markdown]
# ### Αποτέλεσμα: **1104**

# %% [markdown]
# ## Άσκηση 7
#
# $$ (72 - 3\times 8) \times 10^2 \\div (13 - 4) $$

# %%
(72 - 3*8) * 10**2 / (13 - 4)
# Out:
# 533.3333333333334

# %% [markdown]
# ### Αποτέλεσμα: **533.333333**

# %% [markdown]
# ## Άσκηση 8
#
# $$ \frac{95 + 40}{32 \bmod 7} + 5^4 $$

# %%
(95 + 40) / (32 % 7) + 5**4
# Out:
# 658.75

# %% [markdown]
# ### Αποτέλεσμα: **658.75**

# %% [markdown]
# ## Άσκηση 9
#
# $$ \left(40 \times 3 + \frac{68}{5 - 2}\right)^3 $$

# %%
(40 * 3 + 68 / (5 - 2))**3
# Out:
# 2903805.629629629

# %% [markdown]
# ### Αποτέλεσμα: **2903805.62963**

# %% [markdown]
# ## Άσκηση 10
#
# $$ ((18 \times 4) - \tfrac{36}{3})^2 + 7\times 5 - 12^3 $$

# %%
((18 * 4) - 36//3)**2 + 7*5 - 12**3
# Out:
# 1907

# %% [markdown]
# ### Αποτέλεσμα: **1907**

# %% [markdown]
# ## Άσκηση 11
#
# $$ (14 + 26) \times 3^2 - \frac{180}{7 + 8} $$

# %%
(14 + 26) * 3**2 - 180 // (7 + 8)
# Out:
# 348

# %% [markdown]
# ### Αποτέλεσμα: **348**

# %% [markdown]
# ## Άσκηση 12
# $$ \big((50 - 17)(8 + 4) - \tfrac{36}{3}\big)^2 $$

# %%
((50 - 17) * (8 + 4) - 36//3)**2
# Out:
# 147456

# %% [markdown]
# ### Αποτέλεσμα: **147456**

# %% [markdown]
# ## Άσκηση 13
#
# $$ \frac{9^3 - 4^4}{73 \bmod 9} $$

# %%
(9**3 - 4**4) // (73 % 9)
# Out:
# 473

# %% [markdown]
# ### Αποτέλεσμα: **473**

# %% [markdown]
# ## Άσκηση 14
#
# $$ \frac{\big(3(18 - 5)\big)^3}{2 + 7} $$

# %%
(3 * (18 - 5))**3 // (2 + 7)
# Out:
# 6591

# %% [markdown]
# ### Αποτέλεσμα: **6591**

# %% [markdown]
# ## Άσκηση 15
#
# $$ 7^5 - 6^4 + \frac{48}{6}(21 - 13) $$

# %%
7**5 - 6**4 + (48//6) * (21 - 13)
# Out:
# 15575

# %% [markdown]
# ### Αποτέλεσμα: **15575**

# %% [markdown]
# ## Άσκηση 16
#
# $$ \frac{96}{5 + 7} \times \big((15 - 9)\cdot 4\big) - 2^8 $$

# %%
96 // (5 + 7) * ((15 - 9) * 4) - 2**8
# Out:
# -64

# %% [markdown]
# ### Αποτέλεσμα: **-64**

# %% [markdown]
# ## Άσκηση 17
#
# $$ \big(35\times 4 - \tfrac{28}{2}\big)^3 $$

# %%
(35 * 4 - 28//2)**3
# Out:
# 2000376

# %% [markdown]
# ### Αποτέλεσμα: **2000376**

# %% [markdown]
# ## Άσκηση 18
#
# $$ \frac{(11 + 9)(13 - 7)\times 5^2}{4 + 1} $$

# %%
(11 + 9) * (13 - 7) * 5**2 // (4 + 1)
# Out:
# 600

# %% [markdown]
# ### Αποτέλεσμα: **600**

# %% [markdown]
# ## Άσκηση 19
#
# $$ 2^{10} - \big(3^5 - 2^6\big) $$

# %%
2**10 - (3**5 - 2**6)
# Out:
# 845

# %% [markdown]
# ### Αποτέλεσμα: **845**

# %% [markdown]
# ## Άσκηση 20
#
# $$ \big(\tfrac{64}{8} + \tfrac{81}{9}\big)^2 - 7(5 + 6) $$

# %%
(64//8 + 81//9)**2 - 7*(5 + 6)
# Out:
# 212

# %% [markdown]
# ### Αποτέλεσμα: **212**

# %% [markdown]
# ## Άσκηση 21
#
# $$ \frac{(27 - 5\times 3)(14 + 2)}{(19 \bmod 5) + 1} $$

# %%
(27 - 5*3) * (14 + 2) / ((19 % 5) + 1)
# Out:
# 38.4

# %% [markdown]
# ### Αποτέλεσμα: **38.4**

# %% [markdown]
# ## Άσκηση 22
#
# $$ \frac{10^3}{(6 + 4)(3 + 2)} + 17 $$

# %%
10**3 // ((6 + 4) * (3 + 2)) + 17
# Out:
# 37

# %% [markdown]
# ### Αποτέλεσμα: **37**

# %% [markdown]
# ## Άσκηση 23
#
# $$ \big(9\times 7 - 4\times 8\big)^2 + \frac{3^6}{2^3} $$

# %%
(9*7 - 4*8)**2 + 3**6 / 2**3
# Out:
# 1052.125

# %% [markdown]
# ### Αποτέλεσμα: **1052.125**

# %% [markdown]
# ## Άσκηση 24
# ### Μαθηματική Μορφή
# $$ \frac{(5 + 11)(7 + 9) - 3^4}{(8 - 5)\times 3} $$

# %%
((5 + 11) * (7 + 9) - 3**4) / ((8 - 5) * 3)
# Out:
# 19.444444444444443

# %% [markdown]
# ### Αποτέλεσμα: **19.444444**

# %% [markdown]
# ## Άσκηση 25
#
# $$ \big(4^5 - 2^7 + 3\cdot 19\big)  \Big(\tfrac{12}{3} + \tfrac{18}{6}\Big) $$

# %%
(4**5 - 2**7 + 3*19) * (12//3 + 18//6)
# Out:
# 6671

# %% [markdown]
# ### Αποτέλεσμα: **6671**
