# %% [markdown]
# # 1ο Φυλλάδιο Ασκήσεων Python

# %% [markdown]
# ## Άσκηση 1 — Βασικές Μαθηματικές Πράξεις
# Υπολογίστε τις παρακάτω πράξεις σε ένα κελί Python:
# - 25 + 7
# - 120 / 6
# - 3 * 5

# %% [markdown]
# ## Άσκηση 2 — Αλφαριθμητικά, Μεταβλητές και Special Characters
# 1. Δημιουργήστε μια μεταβλητή `name` με το όνομά σας.
# 2. Εκτυπώστε ένα μήνυμα όπως:
# ```
# Hello, Georgios!
# ```

# %% [markdown]
# ## Άσκηση 3 — Indexing & Slicing με Steps
# Δίνεται το αλφαριθμητικό:
# ```python
# s = 'PythonProgramming'
# ```
# Ζητείται:
# - Το πρώτο γράμμα
# - Το έκτο γράμμα
# - Τα 5 πρώτα γράμματα
# - Τα γράμματα από το 0 έως το 10 ανά 2 βήματα```python
# s[0:10:2]```

# %% [markdown]
# ## Άσκηση 4 — Λίστες
# Δίνεται η λίστα:
# ```python
# numbers = [10, 20, 30, 40, 50]
# ```
# Ζητείται:
# - Να προσθέσετε το 60 στη λίστα
# - Να αφαιρέσετε το 30
# - Να τυπώσετε το άθροισμα όλων των τιμών

# %% [markdown]
# ## Άσκηση 5 — Συνδυαστική Άσκηση
# Γράψτε πρόγραμμα που:
# 1. Γράφουμε δύο μεταβλητές, ένα όνομα και μια ηλικία.
# 2. Αποθηκεύει τα στοιχεία σε μια λίστα.
# 3. Εμφανίζει μήνυμα με indexing, π.χ.:
# ```python
# Ο χρήστης ονομάζεται <όνομα> και είναι <ηλικία> ετών.
# ```
# 4. Εκτυπώνει τη λίστα ανάποδα.
