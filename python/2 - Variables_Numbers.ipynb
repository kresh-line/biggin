# %% [markdown]
# # Μαθηματικές πράξεις:

# %% [markdown]
# #### 1. Πρόσθεση (+)

# %%
a = 10
b = 5
a + b

# %% [markdown]
# #### 2. Αφαίρεση (-)

# %%
a - b

# %% [markdown]
# #### 3. Πολλαπλασιασμός (*)

# %%
a * b

# %% [markdown]
# #### 4. Διαίρεση (/)
# Η διαίρεση επιστρέφει πάντα δεκαδικό (float).

# %%
a / b

# %% [markdown]
# #### 5. Ακέραιη Διαίρεση (//)
# Επιστρέφει μόνο το ακέραιο μέρος του αποτελέσματος.

# %%
a // 3

# %% [markdown]
# #### 6. Υπόλοιπο (%)
# Επιστρέφει το υπόλοιπο της διαίρεσης.

# %%
a % 3

# %% [markdown]
# **Προσοχή!**

# %%
1/0

# %% [markdown]
# #### 7. Ύψωση σε Δύναμη (**)

# %%
2 ** 3

# %% [markdown]
# #### 8. Απόλυτη Τιμή (abs)

# %%
abs(-15)

# %% [markdown]
# #### 9. Στρογγυλοποίηση (round)

# %%
round(3.14159, 2)

# %% [markdown]
# # Μεταβλητές
# Όταν γράφουμε ```a=3``` τότε αποθηκεύουμε στη μνήμη του υπολογιστή την τιμή 3. Μπορούμε όποτε θέλουμε μετά να αναφερθούμε σε αυτή την τιμή χρησμοποιώντας το όνομα της μεταβλητής

# %%
a=3

# %%
a

# %%
a+a

# %%
a = 'mitsos'

# %%
a

# %% [markdown]
# Οι δεκαδικές μεταβλητές έχουν συγκεκριμένη ακρίβεια:

# %%
a=5.55545345345234578234659823468237456928374659283746592837465923874659283745692834765928374569283476529873456

# %%
a

# %% [markdown]
# Οι ακέραιες μεταβλητές μπορούν να είναι όσο μεγάλες θέλουμε!

# %%
a = 2984375693847562938476529387456293874562938476529387465923847569238745692387465923874659238746592837465

# %%
a

# %% [markdown]
# Μπορούμε να κάνουμε διάφορες πράξεις μεταξύ μεταβλητών:

# %%
a=3
b=4
print (a+b)

# %% [markdown]
# Τα κενα δεν έχουν σημασία (αρκεί όλες οι γραμμές να ξεκινάνε από το ίδιο κενό).
#
# Όλα τα παρακάτω είναι ισοδύναμα:

# %%
a=3
a = 3
a                             =                                               3

# %% [markdown]
# Στα παρακάτω όμως υπάρχει λάθος!

# %%
a=3
 a=3 # Αυτό ξεκινάει με ένα κενό πιο μέσα!

# %% [markdown]
# ### H συνάρτηση ```input```
# Με τη συνάρτηση ```input``` μπορούμε να πούμε στον χρήστη να εισάγει μία τιμή:

# %%
name = input('What is your name?')

# %%
print (name)

# %% [markdown]
# ### H συνάρτηση ```del```
# Με την ```del``` μπορούμε να "σβήνουμε" τιμές από δομές δεδομένων:

# %%
a = [1,2,3]
print (a)

# %%
del a[1]
print (a)

# %%
a = {'a':2, 'b':3, 'c': 4}
print (a)

# %%
del a['b']
print (a)

# %% [markdown]
# Μπορούμε ακόμα και να "διαγράψουμε" μία μεταβλητή:

# %%
a=3
print (a)

# %%
del a
print (a)

# %% [markdown]
# ### types
# Η συνάρτηση ```type``` μας επιστρέφει τον τύπο μιας μεταβλητής:

# %%
type(3)

# %%
type('hello')

# %%
type(5.2)

# %%
type(True)

# %%
type([1,2,3])

# %%
type({"a":3})

# %% [markdown]
# Πως μπορώ να ελέγξω τι τύπος είναι μια μεταβλητή;

# %%
a='hello'
if type(a) is str:
    print ("This is string")

# %% [markdown]
# Χρησιμοποιώντας το ```type(variable).__name__``` μπορώ να πάρω τον τύπο μιας μεταβλητής ως string:

# %%
a = False
type(a).__name__

# %% [markdown]
# ### is

# %% [markdown]
# Έχουμε δει παραπάνω τον τελεστή ```is```. Το έχουμε χρησιμοποιήσει για να δούμε τι τύπος είναι μία μεταβλητή:

# %%
a = [1,2,3]
type(a) is list

# %% [markdown]
# Η is κοιτάει αν δύο μεταβλητές είναι ίδιες. Δηλαδή είναι οι ίδιες μεταβλητές. Ή αλλιώς κοιτάει αν αναφέρονται στην ίδια θέση μνήμης. Αυτό είναι διαφορετικό από το ίσες: Δύο μεταβλητές είναι *ίσες* (`==`) αν έχουν την ίδια τιμή. Δύο μεταβλητές είναι *ίδιες* αν αναφέρονται στην ίδια θέση μνήμης. Παραδείγματα:

# %%
a = [1,2,3]
b = [1,2,3]
print (a==b)
print (a is b)

# %%
a = [1,2,3]
b = a
print (a==b)
print (a is b)

# %% [markdown]
# ### assert
# Με την ```assert``` ελέγχουνε αν "όλα πάνε καλά" σε κάποιο σημείο του προγράμματος:

# %%
assert True # Όλα καλα

# %%
assert False # Πρόβλημα!

# %% [markdown]
# Την ```assert``` τη χρσησιμοποιούμε σαν quality control. π.χ. πριν από μία διαίρεση:

# %%
d=0
assert d != 0
result = 10/d

# %% [markdown]
# ### Μετατροπή από έναν τύπο σε έναν άλλο
# Η python μας δίνει τις εξής συναρτήσεις για να μετατρέψουμε από έναν τύπο σε έναν άλλο:

# %%
str(3)

# %%
str(True)

# %%
str([1,2,3])

# %%
str({1:2})

# %%
int('3')

# %%
int(4.5)

# %%
int(False)

# %%
int(True)

# %%
int('                       9            ')

# %%
float('4.5')

# %%
float(True)

# %%
bool('False')

# %%
bool('')

# %%
bool([1,2])

# %%
bool({})

# %%
list('hello')

# %%
list({'a':1, 'b': 2})

# %% [markdown]
# **Προσοχή!** Δεν μπορούν να μετατραπούν όλοι οι τύποι σε όλους. Π.χ:

# %%
int('7 hello')

# %%
int([1,2])

# %%
dict(False)

# %% [markdown]
# ### shadowing
# Στη python (σε αντίθεση με άλλες γλώσσες) μπορείτε να χρησιμοποιήσετε ως ονόματα μεταβλητών, ονόματα συναρτήσεων της python. **Προσοχή** αποφύγετε να το κάνετε αυτό γιατί πολύ απλά, "χάνετε" τις συναρτήσεις αυτές!

# %%
list(range(10))

# %%
list = 5

# %%
list(range(10)) # Πετάει μήνημα λάθους. Η list πλέον έχει αντικατασταθεί από το 5!
